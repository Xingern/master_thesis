# %%
# read & manipulate data
import keras_tuner as kt
import os
import numpy as np
import pandas as pd 
import random as rn
import sys
sys.path.append("../scripts")
import tensorflow as tf
import utils

from tensorflow import keras
from keras.layers import Input, Dense, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

RANDOM_SEED = 420
np.random.seed(RANDOM_SEED)
rn.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
tf.config.set_visible_devices([], 'GPU') # Disable GPU since slow on my machine
tf.config.threading.set_inter_op_parallelism_threads(8)

# %%
# Model paths
pkl_path = '/Users/junxingli/Desktop/master_thesis/data/processed/SRD_Lysekil.pkl'
tuner_path = '/Users/junxingli/Desktop/master_thesis/models/ann/'
proj_name = 'transient-time-series-V1/'
best_model_path = tuner_path + proj_name + 'best_model'

# Figure paths
overwrite = False
figs_path = '/Users/junxingli/Desktop/master_thesis/figs/ann/'
plots_path = figs_path + proj_name

# %%
def create_sequences(X, y, time_steps):
    ts = X['Time'].values[time_steps:]
    X = X.drop('Time', axis=1).values
    y = y.drop('Time', axis=1).values

    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(np.hstack([X[i:(i+time_steps)], y[i:(i+time_steps)]]))
        ys.append(y[i+time_steps])

    return np.array(Xs), np.array(ys).reshape(-1, 1), np.array(ts)

def run_preprocessing(time_series=False, case='whole_data'):
    df = pd.read_pickle("../data/processed/SRD_Lysekil.pkl")
    
    if case == "only_stable":
        df = df[df['Status'] == 'Stable']

    X = df.drop(['Status', 'SRD'], axis=1)
    y = df[['Time', 'SRD']]

    if time_series:
        cutoff_date = "2020-06-15 00:00"
        X_train = X[X["Time"] < cutoff_date].copy()
        X_test = X[X["Time"] > cutoff_date].copy()
        y_train = y[y["Time"] < cutoff_date].copy()
        y_test = y[y["Time"] > cutoff_date].copy()

    else:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        
    # Standard scaling the data
    scaler = StandardScaler()
    cols = [col for col in X_train.columns if col != 'Time']
    X_train[cols] = scaler.fit_transform(X_train[cols])
    X_test[cols] = scaler.transform(X_test[cols])

    # Need to reshape since the scaler expects a 2D array
    y_train['SRD'] = scaler.fit_transform(y_train['SRD'].to_numpy().reshape(-1, 1))
    y_test['SRD'] = scaler.transform(y_test['SRD'].to_numpy().reshape(-1, 1))

    return X_train, y_train, X_test, y_test, scaler

time_steps = 15
X_train, y_train, X_test, y_test, scaler = run_preprocessing(case='whole_data', time_series=True)
X_train_seq, y_train_seq, times_train = create_sequences(X_train, y_train, time_steps)
X_test_seq, y_test_seq, times_test = create_sequences(X_test, y_test, time_steps)

input_dim = X_train_seq.shape[-1]
output_dim = y_train_seq.shape[-1]

# %%
class MyHyperModel(kt.HyperModel):
    def build(self, hp): 
        hp_layers = hp.Int('num_layers', 1, 3)
        #hp_normal = hp.Boolean('normalization', default=False)
        hp_learning_rate = hp.Choice('learning_rate', values=[1e-1, 1e-2, 1e-3])
        hp_optimizer = hp.Choice('optimizer', values=['adam'])
            
        model = keras.Sequential()
        model.add(Input(shape=(time_steps, input_dim)))
        for i in range(hp_layers):
            hp_nodes = hp.Int('num_nodes_'+str(i), min_value=20, max_value=100, step=5)
            hp_activation = hp.Choice('activation', values=['relu', 'tanh', 'sigmoid'])
            hp_dropout = hp.Boolean('dropout-normalization', default=False)
            
            model.add(Dense(units=hp_nodes, activation=hp_activation))
            if hp_dropout:
                model.add(Dropout(rate=0.25))
                model.add(BatchNormalization())
        
        model.add(Dense(1, activation='linear'))
        
        # Select optimizer    
        optimizer_dict = {
            'adam': keras.optimizers.legacy.Adam(learning_rate=hp_learning_rate),
            'SGD': keras.optimizers.legacy.SGD(learning_rate=hp_learning_rate),
            'rmsprop': keras.optimizers.legacy.RMSprop(learning_rate=hp_learning_rate)
        }
        model.compile(
            optimizer=optimizer_dict[hp_optimizer],
            loss='mean_squared_error',
            metrics=['mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error']
        )
        
        return model

    def fit(self, hp, model, *args, **kwargs):
        return model.fit(
            *args,
            batch_size=hp.Choice("batch_size", [32, 64, 128]),
            **kwargs,
        )

# %%
tuner = kt.Hyperband(
    MyHyperModel(),
    objective='val_mean_squared_error',
    max_epochs=200,
    overwrite=False,
    directory=tuner_path,
    project_name=proj_name)

reduce_lr = ReduceLROnPlateau(monitor='val_mean_squared_error', factor=0.2,
                              patience=5, min_lr=0.001)

stop_early = EarlyStopping(monitor='val_mean_squared_error', 
                                              patience=10)

tuner.search(X_train_seq,
             y_train_seq, 
             epochs=200, 
             validation_split=0.25, 
             callbacks=[stop_early, reduce_lr])
# Out:
# Reloading Tuner from /Users/junxingli/Desktop/master_thesis/models/ann/transient-time-series-V1/tuner0.json

# %%
class TestCallback(Callback):
    def __init__(self, test_data):
        self.test_data = test_data

    def on_epoch_end(self, epoch, logs=None):
        x, y = self.test_data
        results = self.model.evaluate(x, y, verbose=0)
        logs['test_mse'] = results if isinstance(results, float) else results[1]
        print('\nTest MSE:', logs['test_mse'])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.get_best_models(num_models=1)[0]

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='mean_squared_error', factor=0.2,
                              patience=5, min_lr=0.001)

stop_early = EarlyStopping(monitor='mean_squared_error', 
                                              patience=20)

test_callback = TestCallback((X_test_seq, 
                              y_test_seq))

# Fit the model and save the best model
History = best_model.fit(X_train_seq, 
                         y_train_seq, 
                         epochs=100, 
                         callbacks=[stop_early, reduce_lr, test_callback],
                         validation_split=0)

best_model.summary()
print(best_hps.values)
# Out:
# Epoch 1/100
# 557/588 [===========================>..] - ETA: 0s - loss: 0.9170 - mean_squared_error: 0.9170 - mean_absolute_error: 0.2540 - mean_absolute_percentage_error: 860.9504
# Test MSE: 0.3141193687915802
# 588/588 [==============================] - 1s 1ms/step - loss: 0.8748 - mean_squared_error: 0.8748 - mean_absolute_error: 0.2515 - mean_absolute_percentage_error: 851.4925 - lr: 0.0100 - test_mse: 0.3141
# Epoch 2/100
# 531/588 [==========================>...] - ETA: 0s - loss: 0.9556 - mean_squared_error: 0.9556 - mean_absolute_error: 0.2602 - mean_absolute_percentage_error: 932.1275
# Test MSE: 0.2603401243686676
# 588/588 [==============================] - 1s 960us/step - loss: 0.8803 - mean_squared_error: 0.8803 - mean_absolute_error: 0.2592 - mean_absolute_percentage_error: 918.6905 - lr: 0.0100 - test_mse: 0.2603
# Epoch 3/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.9113 - mean_squared_error: 0.9113 - mean_absolute_error: 0.2620 - mean_absolute_percentage_error: 791.8213
# Test MSE: 0.21564827859401703
# 588/588 [==============================] - 1s 946us/step - loss: 0.8637 - mean_squared_error: 0.8637 - mean_absolute_error: 0.2585 - mean_absolute_percentage_error: 942.8582 - lr: 0.0100 - test_mse: 0.2156
# Epoch 4/100
# 546/588 [==========================>...] - ETA: 0s - loss: 0.8498 - mean_squared_error: 0.8498 - mean_absolute_error: 0.2590 - mean_absolute_percentage_error: 1000.4844
# Test MSE: 0.24074073135852814
# 588/588 [==============================] - 1s 937us/step - loss: 0.8557 - mean_squared_error: 0.8557 - mean_absolute_error: 0.2634 - mean_absolute_percentage_error: 1010.4560 - lr: 0.0100 - test_mse: 0.2407
# Epoch 5/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.9020 - mean_squared_error: 0.9020 - mean_absolute_error: 0.2661 - mean_absolute_percentage_error: 941.7028
# Test MSE: 0.31328827142715454
# 588/588 [==============================] - 1s 943us/step - loss: 0.8673 - mean_squared_error: 0.8673 - mean_absolute_error: 0.2668 - mean_absolute_percentage_error: 925.7559 - lr: 0.0100 - test_mse: 0.3133
# Epoch 6/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.7199 - mean_squared_error: 0.7199 - mean_absolute_error: 0.2701 - mean_absolute_percentage_error: 1105.6079
# Test MSE: 0.33906465768814087
# 588/588 [==============================] - 1s 944us/step - loss: 0.8541 - mean_squared_error: 0.8541 - mean_absolute_error: 0.2692 - mean_absolute_percentage_error: 1097.2402 - lr: 0.0100 - test_mse: 0.3391
# Epoch 7/100
# 580/588 [============================>.] - ETA: 0s - loss: 0.8783 - mean_squared_error: 0.8783 - mean_absolute_error: 0.2632 - mean_absolute_percentage_error: 1027.6921
# Test MSE: 0.5062564015388489
# 588/588 [==============================] - 1s 1ms/step - loss: 0.8702 - mean_squared_error: 0.8702 - mean_absolute_error: 0.2632 - mean_absolute_percentage_error: 1023.9611 - lr: 0.0100 - test_mse: 0.5063
# Epoch 8/100
# 588/588 [==============================] - ETA: 0s - loss: 0.8535 - mean_squared_error: 0.8535 - mean_absolute_error: 0.2543 - mean_absolute_percentage_error: 777.0648
# Test MSE: 0.44813042879104614
# 588/588 [==============================] - 1s 965us/step - loss: 0.8535 - mean_squared_error: 0.8535 - mean_absolute_error: 0.2543 - mean_absolute_percentage_error: 777.0648 - lr: 0.0100 - test_mse: 0.4481
# Epoch 9/100
# 535/588 [==========================>...] - ETA: 0s - loss: 0.9213 - mean_squared_error: 0.9213 - mean_absolute_error: 0.2751 - mean_absolute_percentage_error: 1164.2595
# Test MSE: 0.24438758194446564
# 588/588 [==============================] - 1s 955us/step - loss: 0.8728 - mean_squared_error: 0.8728 - mean_absolute_error: 0.2695 - mean_absolute_percentage_error: 1102.2579 - lr: 0.0100 - test_mse: 0.2444
# Epoch 10/100
# 586/588 [============================>.] - ETA: 0s - loss: 0.8675 - mean_squared_error: 0.8675 - mean_absolute_error: 0.2623 - mean_absolute_percentage_error: 1040.8147
# Test MSE: 0.3014560341835022
# 588/588 [==============================] - 1s 966us/step - loss: 0.8660 - mean_squared_error: 0.8660 - mean_absolute_error: 0.2622 - mean_absolute_percentage_error: 1039.6323 - lr: 0.0100 - test_mse: 0.3015
# Epoch 11/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.8316 - mean_squared_error: 0.8316 - mean_absolute_error: 0.2494 - mean_absolute_percentage_error: 1010.7669
# Test MSE: 0.24318303167819977
# 588/588 [==============================] - 1s 944us/step - loss: 0.8691 - mean_squared_error: 0.8691 - mean_absolute_error: 0.2575 - mean_absolute_percentage_error: 998.1064 - lr: 0.0100 - test_mse: 0.2432
# Epoch 12/100
# 544/588 [==========================>...] - ETA: 0s - loss: 0.9172 - mean_squared_error: 0.9172 - mean_absolute_error: 0.2816 - mean_absolute_percentage_error: 1207.5542
# Test MSE: 0.33258262276649475
# 588/588 [==============================] - 1s 939us/step - loss: 0.8629 - mean_squared_error: 0.8629 - mean_absolute_error: 0.2754 - mean_absolute_percentage_error: 1157.3936 - lr: 0.0100 - test_mse: 0.3326
# Epoch 13/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.9187 - mean_squared_error: 0.9187 - mean_absolute_error: 0.2757 - mean_absolute_percentage_error: 1063.6871
# Test MSE: 0.24023646116256714
# 588/588 [==============================] - 1s 948us/step - loss: 0.8512 - mean_squared_error: 0.8512 - mean_absolute_error: 0.2685 - mean_absolute_percentage_error: 1018.1003 - lr: 0.0100 - test_mse: 0.2402
# Epoch 14/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.8614 - mean_squared_error: 0.8614 - mean_absolute_error: 0.2546 - mean_absolute_percentage_error: 1065.8828
# Test MSE: 0.41422420740127563
# 588/588 [==============================] - 1s 944us/step - loss: 0.8570 - mean_squared_error: 0.8570 - mean_absolute_error: 0.2563 - mean_absolute_percentage_error: 1035.1471 - lr: 0.0100 - test_mse: 0.4142
# Epoch 15/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.8031 - mean_squared_error: 0.8031 - mean_absolute_error: 0.2715 - mean_absolute_percentage_error: 1061.7094
# Test MSE: 0.7450119256973267
# 588/588 [==============================] - 1s 944us/step - loss: 0.8629 - mean_squared_error: 0.8629 - mean_absolute_error: 0.2700 - mean_absolute_percentage_error: 1016.3204 - lr: 0.0100 - test_mse: 0.7450
# Epoch 16/100
# 536/588 [==========================>...] - ETA: 0s - loss: 0.9792 - mean_squared_error: 0.9792 - mean_absolute_error: 0.2849 - mean_absolute_percentage_error: 1173.9167
# Test MSE: 0.2855275869369507
# 588/588 [==============================] - 1s 950us/step - loss: 0.9516 - mean_squared_error: 0.9516 - mean_absolute_error: 0.2852 - mean_absolute_percentage_error: 1180.0481 - lr: 0.0100 - test_mse: 0.2855
# Epoch 17/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.9093 - mean_squared_error: 0.9093 - mean_absolute_error: 0.2719 - mean_absolute_percentage_error: 1091.3723
# Test MSE: 0.2776644229888916
# 588/588 [==============================] - 1s 943us/step - loss: 0.8709 - mean_squared_error: 0.8709 - mean_absolute_error: 0.2690 - mean_absolute_percentage_error: 1054.2009 - lr: 0.0100 - test_mse: 0.2777
# Epoch 18/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7387 - mean_squared_error: 0.7387 - mean_absolute_error: 0.2625 - mean_absolute_percentage_error: 1060.6539
# Test MSE: 0.3907935917377472
# 588/588 [==============================] - 1s 943us/step - loss: 0.8639 - mean_squared_error: 0.8639 - mean_absolute_error: 0.2693 - mean_absolute_percentage_error: 1033.6682 - lr: 0.0100 - test_mse: 0.3908
# Epoch 19/100
# 578/588 [============================>.] - ETA: 0s - loss: 0.8456 - mean_squared_error: 0.8456 - mean_absolute_error: 0.2626 - mean_absolute_percentage_error: 975.3489
# Test MSE: 0.599119246006012
# 588/588 [==============================] - 1s 976us/step - loss: 0.8342 - mean_squared_error: 0.8342 - mean_absolute_error: 0.2623 - mean_absolute_percentage_error: 967.4368 - lr: 0.0020 - test_mse: 0.5991
# Epoch 20/100
# 545/588 [==========================>...] - ETA: 0s - loss: 0.8680 - mean_squared_error: 0.8680 - mean_absolute_error: 0.2793 - mean_absolute_percentage_error: 1022.8372
# Test MSE: 0.4164414703845978
# 588/588 [==============================] - 1s 938us/step - loss: 0.8286 - mean_squared_error: 0.8286 - mean_absolute_error: 0.2775 - mean_absolute_percentage_error: 1006.9349 - lr: 0.0020 - test_mse: 0.4164
# Epoch 21/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.8396 - mean_squared_error: 0.8396 - mean_absolute_error: 0.2629 - mean_absolute_percentage_error: 1026.7446
# Test MSE: 0.5338141918182373
# 588/588 [==============================] - 1s 942us/step - loss: 0.8216 - mean_squared_error: 0.8216 - mean_absolute_error: 0.2649 - mean_absolute_percentage_error: 1038.5797 - lr: 0.0020 - test_mse: 0.5338
# Epoch 22/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.8288 - mean_squared_error: 0.8288 - mean_absolute_error: 0.2958 - mean_absolute_percentage_error: 886.9619
# Test MSE: 0.4335070252418518
# 588/588 [==============================] - 1s 943us/step - loss: 0.8143 - mean_squared_error: 0.8143 - mean_absolute_error: 0.2911 - mean_absolute_percentage_error: 1064.4069 - lr: 0.0020 - test_mse: 0.4335
# Epoch 23/100
# 546/588 [==========================>...] - ETA: 0s - loss: 0.7837 - mean_squared_error: 0.7837 - mean_absolute_error: 0.2688 - mean_absolute_percentage_error: 1095.7338
# Test MSE: 0.4463874399662018
# 588/588 [==============================] - 1s 937us/step - loss: 0.8193 - mean_squared_error: 0.8193 - mean_absolute_error: 0.2705 - mean_absolute_percentage_error: 1077.8304 - lr: 0.0020 - test_mse: 0.4464
# Epoch 24/100
# 543/588 [==========================>...] - ETA: 0s - loss: 0.8470 - mean_squared_error: 0.8470 - mean_absolute_error: 0.2877 - mean_absolute_percentage_error: 1246.8976
# Test MSE: 0.3346141278743744
# 588/588 [==============================] - 1s 947us/step - loss: 0.8153 - mean_squared_error: 0.8153 - mean_absolute_error: 0.2843 - mean_absolute_percentage_error: 1198.9720 - lr: 0.0020 - test_mse: 0.3346
# Epoch 25/100
# 538/588 [==========================>...] - ETA: 0s - loss: 0.8635 - mean_squared_error: 0.8635 - mean_absolute_error: 0.2859 - mean_absolute_percentage_error: 1196.6516
# Test MSE: 0.4766838252544403
# 588/588 [==============================] - 1s 952us/step - loss: 0.8089 - mean_squared_error: 0.8089 - mean_absolute_error: 0.2828 - mean_absolute_percentage_error: 1142.5789 - lr: 0.0020 - test_mse: 0.4767
# Epoch 26/100
# 539/588 [==========================>...] - ETA: 0s - loss: 0.7231 - mean_squared_error: 0.7231 - mean_absolute_error: 0.2627 - mean_absolute_percentage_error: 1059.6719
# Test MSE: 0.6221536993980408
# 588/588 [==============================] - 1s 947us/step - loss: 0.8059 - mean_squared_error: 0.8059 - mean_absolute_error: 0.2675 - mean_absolute_percentage_error: 1045.7225 - lr: 0.0020 - test_mse: 0.6222
# Epoch 27/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.6633 - mean_squared_error: 0.6633 - mean_absolute_error: 0.2616 - mean_absolute_percentage_error: 1078.1276
# Test MSE: 0.612290620803833
# 588/588 [==============================] - 1s 945us/step - loss: 0.8052 - mean_squared_error: 0.8052 - mean_absolute_error: 0.2693 - mean_absolute_percentage_error: 1065.6896 - lr: 0.0020 - test_mse: 0.6123
# Epoch 28/100
# 566/588 [===========================>..] - ETA: 0s - loss: 0.8155 - mean_squared_error: 0.8155 - mean_absolute_error: 0.2942 - mean_absolute_percentage_error: 1147.3073
# Test MSE: 0.37546104192733765
# 588/588 [==============================] - 1s 998us/step - loss: 0.8061 - mean_squared_error: 0.8061 - mean_absolute_error: 0.2939 - mean_absolute_percentage_error: 1126.6960 - lr: 0.0020 - test_mse: 0.3755
# Epoch 29/100
# 539/588 [==========================>...] - ETA: 0s - loss: 0.8588 - mean_squared_error: 0.8588 - mean_absolute_error: 0.2913 - mean_absolute_percentage_error: 1053.3918
# Test MSE: 0.3149844706058502
# 588/588 [==============================] - 1s 944us/step - loss: 0.7997 - mean_squared_error: 0.7997 - mean_absolute_error: 0.2871 - mean_absolute_percentage_error: 1031.8000 - lr: 0.0020 - test_mse: 0.3150
# Epoch 30/100
# 543/588 [==========================>...] - ETA: 0s - loss: 0.8484 - mean_squared_error: 0.8484 - mean_absolute_error: 0.2743 - mean_absolute_percentage_error: 1155.2949
# Test MSE: 0.3320949077606201
# 588/588 [==============================] - 1s 943us/step - loss: 0.7954 - mean_squared_error: 0.7954 - mean_absolute_error: 0.2738 - mean_absolute_percentage_error: 1137.5989 - lr: 0.0020 - test_mse: 0.3321
# Epoch 31/100
# 547/588 [==========================>...] - ETA: 0s - loss: 0.7192 - mean_squared_error: 0.7192 - mean_absolute_error: 0.2822 - mean_absolute_percentage_error: 893.5941
# Test MSE: 0.31051209568977356
# 588/588 [==============================] - 1s 934us/step - loss: 0.7927 - mean_squared_error: 0.7927 - mean_absolute_error: 0.2841 - mean_absolute_percentage_error: 1054.5862 - lr: 0.0020 - test_mse: 0.3105
# Epoch 32/100
# 545/588 [==========================>...] - ETA: 0s - loss: 0.7754 - mean_squared_error: 0.7754 - mean_absolute_error: 0.2715 - mean_absolute_percentage_error: 1068.1068
# Test MSE: 0.5341731905937195
# 588/588 [==============================] - 1s 936us/step - loss: 0.7938 - mean_squared_error: 0.7938 - mean_absolute_error: 0.2734 - mean_absolute_percentage_error: 1049.0382 - lr: 0.0020 - test_mse: 0.5342
# Epoch 33/100
# 545/588 [==========================>...] - ETA: 0s - loss: 0.6693 - mean_squared_error: 0.6693 - mean_absolute_error: 0.2855 - mean_absolute_percentage_error: 1142.4501
# Test MSE: 0.38460761308670044
# 588/588 [==============================] - 1s 938us/step - loss: 0.7856 - mean_squared_error: 0.7856 - mean_absolute_error: 0.2845 - mean_absolute_percentage_error: 1146.1434 - lr: 0.0020 - test_mse: 0.3846
# Epoch 34/100
# 544/588 [==========================>...] - ETA: 0s - loss: 0.7619 - mean_squared_error: 0.7619 - mean_absolute_error: 0.2868 - mean_absolute_percentage_error: 908.3692
# Test MSE: 0.6539309024810791
# 588/588 [==============================] - 1s 943us/step - loss: 0.7887 - mean_squared_error: 0.7887 - mean_absolute_error: 0.2860 - mean_absolute_percentage_error: 1092.7944 - lr: 0.0020 - test_mse: 0.6539
# Epoch 35/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.6392 - mean_squared_error: 0.6392 - mean_absolute_error: 0.2529 - mean_absolute_percentage_error: 758.6281
# Test MSE: 0.48138144612312317
# 588/588 [==============================] - 1s 943us/step - loss: 0.7840 - mean_squared_error: 0.7840 - mean_absolute_error: 0.2582 - mean_absolute_percentage_error: 1039.8610 - lr: 0.0020 - test_mse: 0.4814
# Epoch 36/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.8371 - mean_squared_error: 0.8371 - mean_absolute_error: 0.3013 - mean_absolute_percentage_error: 1133.3303
# Test MSE: 0.4455470144748688
# 588/588 [==============================] - 1s 944us/step - loss: 0.7903 - mean_squared_error: 0.7903 - mean_absolute_error: 0.2971 - mean_absolute_percentage_error: 1113.6366 - lr: 0.0020 - test_mse: 0.4455
# Epoch 37/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.8139 - mean_squared_error: 0.8139 - mean_absolute_error: 0.2702 - mean_absolute_percentage_error: 1053.4729
# Test MSE: 0.38195857405662537
# 588/588 [==============================] - 1s 946us/step - loss: 0.7771 - mean_squared_error: 0.7771 - mean_absolute_error: 0.2707 - mean_absolute_percentage_error: 1033.2976 - lr: 0.0020 - test_mse: 0.3820
# Epoch 38/100
# 578/588 [============================>.] - ETA: 0s - loss: 0.7861 - mean_squared_error: 0.7861 - mean_absolute_error: 0.2826 - mean_absolute_percentage_error: 1101.2816
# Test MSE: 0.39640986919403076
# 588/588 [==============================] - 1s 977us/step - loss: 0.7778 - mean_squared_error: 0.7778 - mean_absolute_error: 0.2824 - mean_absolute_percentage_error: 1093.3221 - lr: 0.0020 - test_mse: 0.3964
# Epoch 39/100
# 543/588 [==========================>...] - ETA: 0s - loss: 0.7217 - mean_squared_error: 0.7217 - mean_absolute_error: 0.2697 - mean_absolute_percentage_error: 1038.3019
# Test MSE: 0.43341538310050964
# 588/588 [==============================] - 1s 939us/step - loss: 0.7816 - mean_squared_error: 0.7816 - mean_absolute_error: 0.2742 - mean_absolute_percentage_error: 1041.1245 - lr: 0.0020 - test_mse: 0.4334
# Epoch 40/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.7966 - mean_squared_error: 0.7966 - mean_absolute_error: 0.2706 - mean_absolute_percentage_error: 1101.7108
# Test MSE: 0.6676019430160522
# 588/588 [==============================] - 1s 941us/step - loss: 0.7848 - mean_squared_error: 0.7848 - mean_absolute_error: 0.2762 - mean_absolute_percentage_error: 1080.7427 - lr: 0.0020 - test_mse: 0.6676
# Epoch 41/100
# 543/588 [==========================>...] - ETA: 0s - loss: 0.8098 - mean_squared_error: 0.8098 - mean_absolute_error: 0.2807 - mean_absolute_percentage_error: 1200.9528
# Test MSE: 0.3622053265571594
# 588/588 [==============================] - 1s 944us/step - loss: 0.7783 - mean_squared_error: 0.7783 - mean_absolute_error: 0.2804 - mean_absolute_percentage_error: 1184.2461 - lr: 0.0020 - test_mse: 0.3622
# Epoch 42/100
# 539/588 [==========================>...] - ETA: 0s - loss: 0.8243 - mean_squared_error: 0.8243 - mean_absolute_error: 0.2954 - mean_absolute_percentage_error: 1404.0806
# Test MSE: 0.38413071632385254
# 588/588 [==============================] - 1s 948us/step - loss: 0.7717 - mean_squared_error: 0.7717 - mean_absolute_error: 0.2920 - mean_absolute_percentage_error: 1354.1885 - lr: 0.0020 - test_mse: 0.3841
# Epoch 43/100
# 543/588 [==========================>...] - ETA: 0s - loss: 0.7615 - mean_squared_error: 0.7615 - mean_absolute_error: 0.2801 - mean_absolute_percentage_error: 1221.3807
# Test MSE: 0.5726748108863831
# 588/588 [==============================] - 1s 941us/step - loss: 0.7787 - mean_squared_error: 0.7787 - mean_absolute_error: 0.2809 - mean_absolute_percentage_error: 1175.2991 - lr: 0.0020 - test_mse: 0.5727
# Epoch 44/100
# 550/588 [===========================>..] - ETA: 0s - loss: 0.6974 - mean_squared_error: 0.6974 - mean_absolute_error: 0.2766 - mean_absolute_percentage_error: 1113.9297
# Test MSE: 0.39887943863868713
# 588/588 [==============================] - 1s 932us/step - loss: 0.7671 - mean_squared_error: 0.7671 - mean_absolute_error: 0.2764 - mean_absolute_percentage_error: 1078.4487 - lr: 0.0020 - test_mse: 0.3989
# Epoch 45/100
# 544/588 [==========================>...] - ETA: 0s - loss: 0.7878 - mean_squared_error: 0.7878 - mean_absolute_error: 0.2877 - mean_absolute_percentage_error: 1109.2662
# Test MSE: 0.4870743155479431
# 588/588 [==============================] - 1s 948us/step - loss: 0.7717 - mean_squared_error: 0.7717 - mean_absolute_error: 0.2851 - mean_absolute_percentage_error: 1085.3684 - lr: 0.0020 - test_mse: 0.4871
# Epoch 46/100
# 531/588 [==========================>...] - ETA: 0s - loss: 0.8137 - mean_squared_error: 0.8137 - mean_absolute_error: 0.2631 - mean_absolute_percentage_error: 1271.7271
# Test MSE: 0.37644410133361816
# 588/588 [==============================] - 1s 959us/step - loss: 0.7753 - mean_squared_error: 0.7753 - mean_absolute_error: 0.2634 - mean_absolute_percentage_error: 1250.1509 - lr: 0.0020 - test_mse: 0.3764
# Epoch 47/100
# 568/588 [===========================>..] - ETA: 0s - loss: 0.7630 - mean_squared_error: 0.7630 - mean_absolute_error: 0.2816 - mean_absolute_percentage_error: 1121.8717
# Test MSE: 0.6171823143959045
# 588/588 [==============================] - 1s 994us/step - loss: 0.7758 - mean_squared_error: 0.7758 - mean_absolute_error: 0.2820 - mean_absolute_percentage_error: 1105.1339 - lr: 0.0020 - test_mse: 0.6172
# Epoch 48/100
# 537/588 [==========================>...] - ETA: 0s - loss: 0.8206 - mean_squared_error: 0.8206 - mean_absolute_error: 0.3003 - mean_absolute_percentage_error: 1106.9780
# Test MSE: 0.3448544144630432
# 588/588 [==============================] - 1s 951us/step - loss: 0.7636 - mean_squared_error: 0.7636 - mean_absolute_error: 0.2939 - mean_absolute_percentage_error: 1118.9807 - lr: 0.0020 - test_mse: 0.3449
# Epoch 49/100
# 536/588 [==========================>...] - ETA: 0s - loss: 0.6597 - mean_squared_error: 0.6597 - mean_absolute_error: 0.2418 - mean_absolute_percentage_error: 1076.4624
# Test MSE: 0.33978888392448425
# 588/588 [==============================] - 1s 951us/step - loss: 0.7686 - mean_squared_error: 0.7686 - mean_absolute_error: 0.2522 - mean_absolute_percentage_error: 1051.9594 - lr: 0.0020 - test_mse: 0.3398
# Epoch 50/100
# 537/588 [==========================>...] - ETA: 0s - loss: 0.8140 - mean_squared_error: 0.8140 - mean_absolute_error: 0.2881 - mean_absolute_percentage_error: 1154.3918
# Test MSE: 0.3200080990791321
# 588/588 [==============================] - 1s 951us/step - loss: 0.7750 - mean_squared_error: 0.7750 - mean_absolute_error: 0.2850 - mean_absolute_percentage_error: 1134.6931 - lr: 0.0020 - test_mse: 0.3200
# Epoch 51/100
# 537/588 [==========================>...] - ETA: 0s - loss: 0.7631 - mean_squared_error: 0.7631 - mean_absolute_error: 0.2678 - mean_absolute_percentage_error: 1083.9872
# Test MSE: 0.6740096807479858
# 588/588 [==============================] - 1s 1ms/step - loss: 0.7620 - mean_squared_error: 0.7620 - mean_absolute_error: 0.2698 - mean_absolute_percentage_error: 1041.8206 - lr: 0.0020 - test_mse: 0.6740
# Epoch 52/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.8087 - mean_squared_error: 0.8087 - mean_absolute_error: 0.2789 - mean_absolute_percentage_error: 1202.4011
# Test MSE: 0.5885177254676819
# 588/588 [==============================] - 1s 943us/step - loss: 0.7721 - mean_squared_error: 0.7721 - mean_absolute_error: 0.2806 - mean_absolute_percentage_error: 1175.5715 - lr: 0.0020 - test_mse: 0.5885
# Epoch 53/100
# 546/588 [==========================>...] - ETA: 0s - loss: 0.8120 - mean_squared_error: 0.8120 - mean_absolute_error: 0.2755 - mean_absolute_percentage_error: 1190.8085
# Test MSE: 0.37998366355895996
# 588/588 [==============================] - 1s 936us/step - loss: 0.7683 - mean_squared_error: 0.7683 - mean_absolute_error: 0.2746 - mean_absolute_percentage_error: 1175.2814 - lr: 0.0020 - test_mse: 0.3800
# Epoch 54/100
# 576/588 [============================>.] - ETA: 0s - loss: 0.7764 - mean_squared_error: 0.7764 - mean_absolute_error: 0.2739 - mean_absolute_percentage_error: 1071.9917
# Test MSE: 0.368375688791275
# 588/588 [==============================] - 1s 979us/step - loss: 0.7675 - mean_squared_error: 0.7675 - mean_absolute_error: 0.2738 - mean_absolute_percentage_error: 1067.4880 - lr: 0.0020 - test_mse: 0.3684
# Epoch 55/100
# 544/588 [==========================>...] - ETA: 0s - loss: 0.7738 - mean_squared_error: 0.7738 - mean_absolute_error: 0.2683 - mean_absolute_percentage_error: 1080.8994
# Test MSE: 0.32206448912620544
# 588/588 [==============================] - 1s 944us/step - loss: 0.7631 - mean_squared_error: 0.7631 - mean_absolute_error: 0.2713 - mean_absolute_percentage_error: 1078.6624 - lr: 0.0020 - test_mse: 0.3221
# Epoch 56/100
# 547/588 [==========================>...] - ETA: 0s - loss: 0.5386 - mean_squared_error: 0.5386 - mean_absolute_error: 0.2625 - mean_absolute_percentage_error: 1075.6852
# Test MSE: 0.5743752121925354
# 588/588 [==============================] - 1s 935us/step - loss: 0.7676 - mean_squared_error: 0.7676 - mean_absolute_error: 0.2684 - mean_absolute_percentage_error: 1070.1021 - lr: 0.0020 - test_mse: 0.5744
# Epoch 57/100
# 543/588 [==========================>...] - ETA: 0s - loss: 0.7848 - mean_squared_error: 0.7848 - mean_absolute_error: 0.2837 - mean_absolute_percentage_error: 1182.7505
# Test MSE: 0.3750259280204773
# 588/588 [==============================] - 1s 940us/step - loss: 0.7595 - mean_squared_error: 0.7595 - mean_absolute_error: 0.2834 - mean_absolute_percentage_error: 1151.7661 - lr: 0.0010 - test_mse: 0.3750
# Epoch 58/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.7615 - mean_squared_error: 0.7615 - mean_absolute_error: 0.2792 - mean_absolute_percentage_error: 1108.4996
# Test MSE: 0.31855711340904236
# 588/588 [==============================] - 1s 943us/step - loss: 0.7532 - mean_squared_error: 0.7532 - mean_absolute_error: 0.2775 - mean_absolute_percentage_error: 1086.4985 - lr: 0.0010 - test_mse: 0.3186
# Epoch 59/100
# 576/588 [============================>.] - ETA: 0s - loss: 0.7651 - mean_squared_error: 0.7651 - mean_absolute_error: 0.2796 - mean_absolute_percentage_error: 1164.4802
# Test MSE: 0.30734339356422424
# 588/588 [==============================] - 1s 982us/step - loss: 0.7529 - mean_squared_error: 0.7529 - mean_absolute_error: 0.2787 - mean_absolute_percentage_error: 1160.7878 - lr: 0.0010 - test_mse: 0.3073
# Epoch 60/100
# 548/588 [==========================>...] - ETA: 0s - loss: 0.7997 - mean_squared_error: 0.7997 - mean_absolute_error: 0.2669 - mean_absolute_percentage_error: 1166.0457
# Test MSE: 0.34787115454673767
# 588/588 [==============================] - 1s 932us/step - loss: 0.7564 - mean_squared_error: 0.7564 - mean_absolute_error: 0.2656 - mean_absolute_percentage_error: 1141.7323 - lr: 0.0010 - test_mse: 0.3479
# Epoch 61/100
# 552/588 [===========================>..] - ETA: 0s - loss: 0.7763 - mean_squared_error: 0.7763 - mean_absolute_error: 0.2773 - mean_absolute_percentage_error: 1164.0341
# Test MSE: 0.30076277256011963
# 588/588 [==============================] - 1s 927us/step - loss: 0.7539 - mean_squared_error: 0.7539 - mean_absolute_error: 0.2756 - mean_absolute_percentage_error: 1127.2850 - lr: 0.0010 - test_mse: 0.3008
# Epoch 62/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.7751 - mean_squared_error: 0.7751 - mean_absolute_error: 0.2756 - mean_absolute_percentage_error: 853.8911
# Test MSE: 0.27679821848869324
# 588/588 [==============================] - 1s 943us/step - loss: 0.7415 - mean_squared_error: 0.7415 - mean_absolute_error: 0.2744 - mean_absolute_percentage_error: 1222.2694 - lr: 0.0010 - test_mse: 0.2768
# Epoch 63/100
# 536/588 [==========================>...] - ETA: 0s - loss: 0.7828 - mean_squared_error: 0.7828 - mean_absolute_error: 0.2632 - mean_absolute_percentage_error: 1040.8906
# Test MSE: 0.32198622822761536
# 588/588 [==============================] - 1s 954us/step - loss: 0.7479 - mean_squared_error: 0.7479 - mean_absolute_error: 0.2645 - mean_absolute_percentage_error: 1009.5829 - lr: 0.0010 - test_mse: 0.3220
# Epoch 64/100
# 538/588 [==========================>...] - ETA: 0s - loss: 0.7703 - mean_squared_error: 0.7703 - mean_absolute_error: 0.2771 - mean_absolute_percentage_error: 1212.7948
# Test MSE: 0.322511225938797
# 588/588 [==============================] - 1s 949us/step - loss: 0.7487 - mean_squared_error: 0.7487 - mean_absolute_error: 0.2760 - mean_absolute_percentage_error: 1215.9016 - lr: 0.0010 - test_mse: 0.3225
# Epoch 65/100
# 539/588 [==========================>...] - ETA: 0s - loss: 0.8075 - mean_squared_error: 0.8075 - mean_absolute_error: 0.2844 - mean_absolute_percentage_error: 1200.4563
# Test MSE: 0.30739519000053406
# 588/588 [==============================] - 1s 951us/step - loss: 0.7502 - mean_squared_error: 0.7502 - mean_absolute_error: 0.2794 - mean_absolute_percentage_error: 1167.4460 - lr: 0.0010 - test_mse: 0.3074
# Epoch 66/100
# 575/588 [============================>.] - ETA: 0s - loss: 0.7642 - mean_squared_error: 0.7642 - mean_absolute_error: 0.2689 - mean_absolute_percentage_error: 1152.0312
# Test MSE: 0.2963162660598755
# 588/588 [==============================] - 1s 983us/step - loss: 0.7504 - mean_squared_error: 0.7504 - mean_absolute_error: 0.2681 - mean_absolute_percentage_error: 1141.6454 - lr: 0.0010 - test_mse: 0.2963
# Epoch 67/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7706 - mean_squared_error: 0.7706 - mean_absolute_error: 0.2660 - mean_absolute_percentage_error: 1032.3621
# Test MSE: 0.2807304263114929
# 588/588 [==============================] - 1s 945us/step - loss: 0.7557 - mean_squared_error: 0.7557 - mean_absolute_error: 0.2664 - mean_absolute_percentage_error: 1009.7184 - lr: 0.0010 - test_mse: 0.2807
# Epoch 68/100
# 536/588 [==========================>...] - ETA: 0s - loss: 0.8014 - mean_squared_error: 0.8014 - mean_absolute_error: 0.2790 - mean_absolute_percentage_error: 1064.2590
# Test MSE: 0.3080768585205078
# 588/588 [==============================] - 1s 950us/step - loss: 0.7451 - mean_squared_error: 0.7451 - mean_absolute_error: 0.2777 - mean_absolute_percentage_error: 1034.6427 - lr: 0.0010 - test_mse: 0.3081
# Epoch 69/100
# 531/588 [==========================>...] - ETA: 0s - loss: 0.8159 - mean_squared_error: 0.8159 - mean_absolute_error: 0.2828 - mean_absolute_percentage_error: 1085.0179
# Test MSE: 0.2901119589805603
# 588/588 [==============================] - 1s 957us/step - loss: 0.7519 - mean_squared_error: 0.7519 - mean_absolute_error: 0.2783 - mean_absolute_percentage_error: 1073.0632 - lr: 0.0010 - test_mse: 0.2901
# Epoch 70/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.7434 - mean_squared_error: 0.7434 - mean_absolute_error: 0.2535 - mean_absolute_percentage_error: 1003.9412
# Test MSE: 0.2964189648628235
# 588/588 [==============================] - 1s 945us/step - loss: 0.7494 - mean_squared_error: 0.7494 - mean_absolute_error: 0.2574 - mean_absolute_percentage_error: 1045.3875 - lr: 0.0010 - test_mse: 0.2964
# Epoch 71/100
# 573/588 [============================>.] - ETA: 0s - loss: 0.7673 - mean_squared_error: 0.7673 - mean_absolute_error: 0.2752 - mean_absolute_percentage_error: 1151.2229
# Test MSE: 0.29274100065231323
# 588/588 [==============================] - 1s 987us/step - loss: 0.7521 - mean_squared_error: 0.7521 - mean_absolute_error: 0.2743 - mean_absolute_percentage_error: 1153.8192 - lr: 0.0010 - test_mse: 0.2927
# Epoch 72/100
# 533/588 [==========================>...] - ETA: 0s - loss: 0.7019 - mean_squared_error: 0.7019 - mean_absolute_error: 0.2695 - mean_absolute_percentage_error: 1220.7692
# Test MSE: 0.3092982769012451
# 588/588 [==============================] - 1s 954us/step - loss: 0.7415 - mean_squared_error: 0.7415 - mean_absolute_error: 0.2709 - mean_absolute_percentage_error: 1187.5610 - lr: 0.0010 - test_mse: 0.3093
# Epoch 73/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7554 - mean_squared_error: 0.7554 - mean_absolute_error: 0.2813 - mean_absolute_percentage_error: 856.5828
# Test MSE: 0.4776243567466736
# 588/588 [==============================] - 1s 943us/step - loss: 0.7445 - mean_squared_error: 0.7445 - mean_absolute_error: 0.2794 - mean_absolute_percentage_error: 1183.9026 - lr: 0.0010 - test_mse: 0.4776
# Epoch 74/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7990 - mean_squared_error: 0.7990 - mean_absolute_error: 0.2685 - mean_absolute_percentage_error: 1050.2444
# Test MSE: 0.278615802526474
# 588/588 [==============================] - 1s 945us/step - loss: 0.7472 - mean_squared_error: 0.7472 - mean_absolute_error: 0.2659 - mean_absolute_percentage_error: 1026.3905 - lr: 0.0010 - test_mse: 0.2786
# Epoch 75/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.7570 - mean_squared_error: 0.7570 - mean_absolute_error: 0.2584 - mean_absolute_percentage_error: 1280.5271
# Test MSE: 0.2797544300556183
# 588/588 [==============================] - 1s 944us/step - loss: 0.7480 - mean_squared_error: 0.7480 - mean_absolute_error: 0.2618 - mean_absolute_percentage_error: 1248.5796 - lr: 0.0010 - test_mse: 0.2798
# Epoch 76/100
# 547/588 [==========================>...] - ETA: 0s - loss: 0.5830 - mean_squared_error: 0.5830 - mean_absolute_error: 0.2663 - mean_absolute_percentage_error: 1144.6917
# Test MSE: 0.2586267590522766
# 588/588 [==============================] - 1s 943us/step - loss: 0.7430 - mean_squared_error: 0.7430 - mean_absolute_error: 0.2724 - mean_absolute_percentage_error: 1125.3126 - lr: 0.0010 - test_mse: 0.2586
# Epoch 77/100
# 574/588 [============================>.] - ETA: 0s - loss: 0.7436 - mean_squared_error: 0.7436 - mean_absolute_error: 0.2753 - mean_absolute_percentage_error: 1134.1045
# Test MSE: 0.272773414850235
# 588/588 [==============================] - 1s 988us/step - loss: 0.7534 - mean_squared_error: 0.7534 - mean_absolute_error: 0.2759 - mean_absolute_percentage_error: 1133.4478 - lr: 0.0010 - test_mse: 0.2728
# Epoch 78/100
# 539/588 [==========================>...] - ETA: 0s - loss: 0.6091 - mean_squared_error: 0.6091 - mean_absolute_error: 0.2643 - mean_absolute_percentage_error: 1176.6216
# Test MSE: 0.3799591064453125
# 588/588 [==============================] - 1s 949us/step - loss: 0.7450 - mean_squared_error: 0.7450 - mean_absolute_error: 0.2685 - mean_absolute_percentage_error: 1132.9202 - lr: 0.0010 - test_mse: 0.3800
# Epoch 79/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7765 - mean_squared_error: 0.7765 - mean_absolute_error: 0.2808 - mean_absolute_percentage_error: 1099.0614
# Test MSE: 0.3153110444545746
# 588/588 [==============================] - 1s 945us/step - loss: 0.7451 - mean_squared_error: 0.7451 - mean_absolute_error: 0.2801 - mean_absolute_percentage_error: 1113.5492 - lr: 0.0010 - test_mse: 0.3153
# Epoch 80/100
# 536/588 [==========================>...] - ETA: 0s - loss: 0.7795 - mean_squared_error: 0.7795 - mean_absolute_error: 0.2814 - mean_absolute_percentage_error: 1271.7330
# Test MSE: 0.34743961691856384
# 588/588 [==============================] - 1s 950us/step - loss: 0.7490 - mean_squared_error: 0.7490 - mean_absolute_error: 0.2805 - mean_absolute_percentage_error: 1223.4746 - lr: 0.0010 - test_mse: 0.3474
# Epoch 81/100
# 529/588 [=========================>....] - ETA: 0s - loss: 0.8119 - mean_squared_error: 0.8119 - mean_absolute_error: 0.2725 - mean_absolute_percentage_error: 1080.6685
# Test MSE: 0.2976183295249939
# 588/588 [==============================] - 1s 959us/step - loss: 0.7480 - mean_squared_error: 0.7480 - mean_absolute_error: 0.2704 - mean_absolute_percentage_error: 1082.3130 - lr: 0.0010 - test_mse: 0.2976
# Epoch 82/100
# 560/588 [===========================>..] - ETA: 0s - loss: 0.7102 - mean_squared_error: 0.7102 - mean_absolute_error: 0.2673 - mean_absolute_percentage_error: 1008.6479
# Test MSE: 0.29198315739631653
# 588/588 [==============================] - 1s 1ms/step - loss: 0.7417 - mean_squared_error: 0.7417 - mean_absolute_error: 0.2693 - mean_absolute_percentage_error: 1002.7255 - lr: 0.0010 - test_mse: 0.2920
# Epoch 83/100
# 537/588 [==========================>...] - ETA: 0s - loss: 0.7703 - mean_squared_error: 0.7703 - mean_absolute_error: 0.2792 - mean_absolute_percentage_error: 1168.8809
# Test MSE: 0.49751776456832886
# 588/588 [==============================] - 1s 951us/step - loss: 0.7433 - mean_squared_error: 0.7433 - mean_absolute_error: 0.2776 - mean_absolute_percentage_error: 1141.5731 - lr: 0.0010 - test_mse: 0.4975
# Epoch 84/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7636 - mean_squared_error: 0.7636 - mean_absolute_error: 0.2654 - mean_absolute_percentage_error: 965.1068
# Test MSE: 0.3484247326850891
# 588/588 [==============================] - 1s 946us/step - loss: 0.7435 - mean_squared_error: 0.7435 - mean_absolute_error: 0.2661 - mean_absolute_percentage_error: 945.4469 - lr: 0.0010 - test_mse: 0.3484
# Epoch 85/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.6464 - mean_squared_error: 0.6464 - mean_absolute_error: 0.2685 - mean_absolute_percentage_error: 1182.2144
# Test MSE: 0.2891857624053955
# 588/588 [==============================] - 1s 943us/step - loss: 0.7426 - mean_squared_error: 0.7426 - mean_absolute_error: 0.2713 - mean_absolute_percentage_error: 1145.9047 - lr: 0.0010 - test_mse: 0.2892
# Epoch 86/100
# 576/588 [============================>.] - ETA: 0s - loss: 0.7325 - mean_squared_error: 0.7325 - mean_absolute_error: 0.2619 - mean_absolute_percentage_error: 1106.5570
# Test MSE: 0.3785031735897064
# 588/588 [==============================] - 1s 1ms/step - loss: 0.7439 - mean_squared_error: 0.7439 - mean_absolute_error: 0.2627 - mean_absolute_percentage_error: 1097.9524 - lr: 0.0010 - test_mse: 0.3785
# Epoch 87/100
# 542/588 [==========================>...] - ETA: 0s - loss: 0.7280 - mean_squared_error: 0.7280 - mean_absolute_error: 0.2715 - mean_absolute_percentage_error: 1205.3138
# Test MSE: 0.31018784642219543
# 588/588 [==============================] - 1s 941us/step - loss: 0.7423 - mean_squared_error: 0.7423 - mean_absolute_error: 0.2717 - mean_absolute_percentage_error: 1161.5726 - lr: 0.0010 - test_mse: 0.3102
# Epoch 88/100
# 541/588 [==========================>...] - ETA: 0s - loss: 0.6717 - mean_squared_error: 0.6717 - mean_absolute_error: 0.2740 - mean_absolute_percentage_error: 1190.9170
# Test MSE: 0.35262247920036316
# 588/588 [==============================] - 1s 944us/step - loss: 0.7386 - mean_squared_error: 0.7386 - mean_absolute_error: 0.2775 - mean_absolute_percentage_error: 1176.4353 - lr: 0.0010 - test_mse: 0.3526
# Epoch 89/100
# 532/588 [==========================>...] - ETA: 0s - loss: 0.7957 - mean_squared_error: 0.7957 - mean_absolute_error: 0.2746 - mean_absolute_percentage_error: 1206.8997
# Test MSE: 0.28698599338531494
# 588/588 [==============================] - 1s 955us/step - loss: 0.7494 - mean_squared_error: 0.7494 - mean_absolute_error: 0.2731 - mean_absolute_percentage_error: 1172.2548 - lr: 0.0010 - test_mse: 0.2870
# Epoch 90/100
# 545/588 [==========================>...] - ETA: 0s - loss: 0.7845 - mean_squared_error: 0.7845 - mean_absolute_error: 0.2702 - mean_absolute_percentage_error: 1172.1445
# Test MSE: 0.2617795765399933
# 588/588 [==============================] - 1s 940us/step - loss: 0.7500 - mean_squared_error: 0.7500 - mean_absolute_error: 0.2690 - mean_absolute_percentage_error: 1129.9756 - lr: 0.0010 - test_mse: 0.2618
# Epoch 91/100
# 576/588 [============================>.] - ETA: 0s - loss: 0.7567 - mean_squared_error: 0.7567 - mean_absolute_error: 0.2719 - mean_absolute_percentage_error: 1014.7610
# Test MSE: 0.2836974561214447
# 588/588 [==============================] - 1s 980us/step - loss: 0.7452 - mean_squared_error: 0.7452 - mean_absolute_error: 0.2714 - mean_absolute_percentage_error: 1012.8670 - lr: 0.0010 - test_mse: 0.2837
# Epoch 92/100
# 545/588 [==========================>...] - ETA: 0s - loss: 0.7804 - mean_squared_error: 0.7804 - mean_absolute_error: 0.2723 - mean_absolute_percentage_error: 1234.2302
# Test MSE: 0.24212251603603363
# 588/588 [==============================] - 1s 937us/step - loss: 0.7414 - mean_squared_error: 0.7414 - mean_absolute_error: 0.2706 - mean_absolute_percentage_error: 1219.5641 - lr: 0.0010 - test_mse: 0.2421
# Epoch 93/100
# 548/588 [==========================>...] - ETA: 0s - loss: 0.7554 - mean_squared_error: 0.7554 - mean_absolute_error: 0.2730 - mean_absolute_percentage_error: 840.0854
# Test MSE: 0.2537154257297516
# 588/588 [==============================] - 1s 933us/step - loss: 0.7376 - mean_squared_error: 0.7376 - mean_absolute_error: 0.2718 - mean_absolute_percentage_error: 1056.3368 - lr: 0.0010 - test_mse: 0.2537
# Epoch 94/100
# 547/588 [==========================>...] - ETA: 0s - loss: 0.7633 - mean_squared_error: 0.7633 - mean_absolute_error: 0.2626 - mean_absolute_percentage_error: 1042.0094
# Test MSE: 0.3119041621685028
# 588/588 [==============================] - 1s 933us/step - loss: 0.7493 - mean_squared_error: 0.7493 - mean_absolute_error: 0.2628 - mean_absolute_percentage_error: 1014.9110 - lr: 0.0010 - test_mse: 0.3119
# Epoch 95/100
# 579/588 [============================>.] - ETA: 0s - loss: 0.7517 - mean_squared_error: 0.7517 - mean_absolute_error: 0.2723 - mean_absolute_percentage_error: 1162.8993
# Test MSE: 0.2786337733268738
# 588/588 [==============================] - 1s 976us/step - loss: 0.7440 - mean_squared_error: 0.7440 - mean_absolute_error: 0.2719 - mean_absolute_percentage_error: 1152.5885 - lr: 0.0010 - test_mse: 0.2786
# Epoch 96/100
# 547/588 [==========================>...] - ETA: 0s - loss: 0.7424 - mean_squared_error: 0.7424 - mean_absolute_error: 0.2713 - mean_absolute_percentage_error: 1087.7533
# Test MSE: 0.5238162875175476
# 588/588 [==============================] - 1s 941us/step - loss: 0.7364 - mean_squared_error: 0.7364 - mean_absolute_error: 0.2722 - mean_absolute_percentage_error: 1058.1400 - lr: 0.0010 - test_mse: 0.5238
# Epoch 97/100
# 544/588 [==========================>...] - ETA: 0s - loss: 0.7825 - mean_squared_error: 0.7825 - mean_absolute_error: 0.2649 - mean_absolute_percentage_error: 1244.2762
# Test MSE: 0.2540675103664398
# 588/588 [==============================] - 1s 939us/step - loss: 0.7453 - mean_squared_error: 0.7453 - mean_absolute_error: 0.2651 - mean_absolute_percentage_error: 1208.3848 - lr: 0.0010 - test_mse: 0.2541
# Epoch 98/100
# 586/588 [============================>.] - ETA: 0s - loss: 0.7474 - mean_squared_error: 0.7474 - mean_absolute_error: 0.2724 - mean_absolute_percentage_error: 1132.3738
# Test MSE: 0.3095113933086395
# 588/588 [==============================] - 1s 1ms/step - loss: 0.7462 - mean_squared_error: 0.7462 - mean_absolute_error: 0.2724 - mean_absolute_percentage_error: 1130.9294 - lr: 0.0010 - test_mse: 0.3095
# Epoch 99/100
# 550/588 [===========================>..] - ETA: 0s - loss: 0.6479 - mean_squared_error: 0.6479 - mean_absolute_error: 0.2634 - mean_absolute_percentage_error: 1062.4921
# Test MSE: 0.3356982469558716
# 588/588 [==============================] - 1s 1ms/step - loss: 0.7413 - mean_squared_error: 0.7413 - mean_absolute_error: 0.2675 - mean_absolute_percentage_error: 1050.4310 - lr: 0.0010 - test_mse: 0.3357
# Epoch 100/100
# 540/588 [==========================>...] - ETA: 0s - loss: 0.7374 - mean_squared_error: 0.7374 - mean_absolute_error: 0.2681 - mean_absolute_percentage_error: 1193.4008
# Test MSE: 0.2791610062122345
# 588/588 [==============================] - 1s 945us/step - loss: 0.7417 - mean_squared_error: 0.7417 - mean_absolute_error: 0.2699 - mean_absolute_percentage_error: 1162.6752 - lr: 0.0010 - test_mse: 0.2792
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15, 50)            1050
#
#  dropout (Dropout)           (None, 15, 50)            0
#
#  batch_normalization (BatchN  (None, 15, 50)           200
#  ormalization)
#
#  dense_1 (Dense)             (None, 15, 1)             51
#
# =================================================================
# Total params: 1,301
# Trainable params: 1,201
# Non-trainable params: 100
# _________________________________________________________________
# {'num_layers': 1, 'learning_rate': 0.01, 'optimizer': 'adam', 'num_nodes_0': 50, 'activation': 'tanh', 'dropout-normalization': True, 'num_nodes_1': 50, 'batch_size': 64, 'num_nodes_2': 75, 'tuner/epochs': 67, 'tuner/initial_epoch': 23, 'tuner/bracket': 4, 'tuner/round': 3, 'tuner/trial_id': '0131'}

# %%
if overwrite or not os.path.exists(best_model_path):
    print(f"Model was saved to {best_model_path}")
    best_model.save(best_model_path)
else:
    print(f"Model file already exists at {best_model_path}. Set 'overwrite=True' to overwrite the file.")
    
utils.plot_mse_over_epochs(History, plots_path, overwrite=overwrite)
# Out:
# Model file already exists at /Users/junxingli/Desktop/master_thesis/models/ann/transient-time-series-V1/best_model. Set 'overwrite=True' to overwrite the file.
# File Loss_over_epoch.pdf was saved to /Users/junxingli/Desktop/master_thesis/figs/ann/transient-time-series-V1/Loss_over_epoch.pdf.

# %%
def prediction_df(model, scaler, X_seq, y_seq, times):
    y_pred = model.predict(X_seq)
    y_pred = np.mean(y_pred, axis=1)
    y_pred = scaler.inverse_transform(y_pred).reshape(-1)
    y_actual = scaler.inverse_transform(y_seq).reshape(-1)

    df_res = pd.DataFrame({'Time': times, 
                           'Actual': y_actual, 
                           'Predicted': y_pred})
    df_res.sort_values('Time')
    
    rmse = mean_squared_error(df_res['Actual'], df_res['Predicted'], squared=False)
    r2 = r2_score(df_res['Actual'], df_res['Predicted'])
    print(f"Root Mean Squared Error: {rmse}")
    print(f"R2 Score: {r2}")
    
    return df_res, rmse

loaded_model = keras.models.load_model(best_model_path)
df_train, rmse_train = prediction_df(loaded_model, scaler, X_train_seq, y_train_seq, times_train)
df_test, rmse_test = prediction_df(loaded_model, scaler, X_test_seq, y_test_seq, times_test)

utils.plot_time_predictions(df_train, df_test, plots_path, overwrite, limit=[3.5, 4.4], linewidth=0)
# Out:
# 588/588 [==============================] - 0s 388us/step
# Root Mean Squared Error: 0.5956749174353673
# R2 Score: 0.2229812080851079
# 88/88 [==============================] - 0s 382us/step
# Root Mean Squared Error: 0.47635780903179414
# R2 Score: -1.876353902626207
# File Predictions.pdf was saved to /Users/junxingli/Desktop/master_thesis/figs/ann/transient-time-series-V1/Predictions.pdf.

# %%
utils.make_evaluation_plots(df_train,
                            df_test,
                            "ANN-Time-Series-V1",
                            plots_path, 
                            overwrite=False, 
                            limit=[3.2, 5], 
                            error_line=0.05, 
                            res_limit=[-1.3, 0.7], 
                            mean=pd.read_pickle("../data/processed/SRD_Lysekil.pkl")['SRD'].mean())
# Out:
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# File ANN-Time-Series-V1_parity_plot.pdf was saved to /Users/junxingli/Desktop/master_thesis/figs/ann/transient-time-series-V1/ANN-Time-Series-V1_parity_plot.pdf.
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# File ANN-Time-Series-V1_residuals_plot.pdf was saved to /Users/junxingli/Desktop/master_thesis/figs/ann/transient-time-series-V1/ANN-Time-Series-V1_residuals_plot.pdf.
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/XingsKernel/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# File ANN-Time-Series-V1_KDE_plot.pdf was saved to /Users/junxingli/Desktop/master_thesis/figs/ann/transient-time-series-V1/ANN-Time-Series-V1_KDE_plot.pdf.
