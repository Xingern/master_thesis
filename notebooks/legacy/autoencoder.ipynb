# %% [markdown]
# # Autoenccoder for transient data detection

# %% [markdown]
# Based on the following Kaggle: https://www.kaggle.com/code/robinteuwens/anomaly-detection-with-auto-encoders

# %% [markdown]
# ## Preprocessing and t-SNE

# %%
# read & manipulate data
import pandas as pd 
import numpy as np
import tensorflow as tf

# visualisations
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid', context='notebook')

# misc
import random as rn

# load the dataset
import sys
sys.path.append("../scripts")
df = pd.read_pickle("../data/processed/SRD_Lysekil.pkl")

# manual parameters
RANDOM_SEED = 42
TRAINING_SAMPLE = 15000
VALIDATE_SIZE = 0.2

# setting random seeds for libraries to ensure reproducibility
np.random.seed(RANDOM_SEED)
rn.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
# Out:
# 2024-02-29 17:54:27.745444: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df.set_index('Time', inplace=True)
df['Status'] = df['Status'].map({'Unstable': 1, 'Stable': 0})

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# dropping redundant columns
#df = df.drop(['time', 'amount'], axis=1)

# splitting by class
fraud = df[df['Status'] == 1]
clean = df[df['Status'] == 0]

# undersample clean transactions
clean_undersampled = clean.sample(
    int(len(fraud) * RATIO_TO_FRAUD),
    random_state=RANDOM_SEED,
    replace=True
)

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean_undersampled])
column_names = list(visualisation_initial.drop('Status', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('Status', axis=1).values, \
                   visualisation_initial['Status'].values
                   
print(f"""The non-fraud dataset has been undersampled from {len(clean):,} to {len(clean_undersampled):,}.
This represents a ratio of {RATIO_TO_FRAUD}:1 to fraud.""")
# Out:
# The non-fraud dataset has been undersampled from 15,604 to 94,305.
# This represents a ratio of 15:1 to fraud.

# %%
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

def tsne_scatter(features, labels, dimensions=2, save_as='graph.png'):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions, random_state=RANDOM_SEED).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

    # storing it to be displayed later
    plt.legend(loc='best')
    plt.savefig(save_as)
    plt.show

# %%
#tsne_scatter(features, labels, dimensions=2)

# %%
print(f"""Shape of the datasets:
    clean (rows, cols) = {clean.shape}
    fraud (rows, cols) = {fraud.shape}""")
# Out:
# Shape of the datasets:
#     clean (rows, cols) = (15604, 16)
#     fraud (rows, cols) = (6287, 16)

# %%
# shuffle our training set
clean = clean.sample(frac=1).reset_index(drop=True)

# training set: exlusively non-fraud transactions
X_train = clean.iloc[:TRAINING_SAMPLE].drop('Status', axis=1)

# testing  set: the remaining non-fraud + all the fraud 
X_test = clean.iloc[TRAINING_SAMPLE:].append(fraud).sample(frac=1)
# Out:
# /var/folders/p2/j2dh2mts4mz6_nskglkx1g9m0000gn/T/ipykernel_36099/1116593182.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_test = clean.iloc[TRAINING_SAMPLE:].append(fraud).sample(frac=1)

# %%
print(f"""Our testing set is composed as follows:

{X_test['Status'].value_counts()}""")
# Out:
# Our testing set is composed as follows:
#
# 1.0    6287
# 0.0     604
# Name: Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# train // validate - no labels since they're all clean anyway
X_train, X_validate = train_test_split(X_train, 
                                       test_size=VALIDATE_SIZE, 
                                       random_state=RANDOM_SEED)

# manually splitting the labels from the test df
X_test, y_test = X_test.drop('Status', axis=1).values, X_test['Status'].values

# %%
print(f"""Shape of the datasets:
    training (rows, cols) = {X_train.shape}
    validate (rows, cols) = {X_validate.shape}
    holdout  (rows, cols) = {X_test.shape}""")
# Out:
# Shape of the datasets:
#     training (rows, cols) = (12000, 15)
#     validate (rows, cols) = (3000, 15)
#     holdout  (rows, cols) = (6891, 15)

# %% [markdown]
# ## Normalising & Standardising

# %%
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

# configure our pipeline
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])

# %%
# get normalization parameters by fitting to the training data
pipeline.fit(X_train)

# transform the training and validation data with these parameters
X_train_transformed = pipeline.transform(X_train)
X_validate_transformed = pipeline.transform(X_validate)

# %%
g = sns.PairGrid(X_train.iloc[:,:3].sample(600, random_state=RANDOM_SEED))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Before:')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot);

# %%
g = sns.PairGrid(pd.DataFrame(X_train_transformed, columns=column_names).iloc[:,:3].sample(600, random_state=RANDOM_SEED))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('After:')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot);

# %% [markdown]
# ## Training the auto-encoder

# %%
# Load the extension and start TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# Traceback (most recent call last):
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/bin/tensorboard", line 7, in <module>
#     from tensorboard.main import run_main
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/tensorboard/main.py", line 27, in <module>
#     from tensorboard import default
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/tensorboard/default.py", line 33, in <module>
#     from tensorboard.plugins.audio import audio_plugin
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/tensorboard/plugins/audio/audio_plugin.py", line 23, in <module>
#     from tensorboard import plugin_util
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/tensorboard/plugin_util.py", line 78, in <module>
#     _MARKDOWN_STORE = _MarkdownStore()
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/tensorboard/plugin_util.py", line 70, in __init__
#     self.markdown = markdown.Markdown(
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/markdown/core.py", line 126, in __init__
#     self.registerExtensions(extensions=kwargs.get('extensions', []),
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/markdown/core.py", line 179, in registerExtensions
#     ext = self.build_extension(ext, configs.get(ext, {}))
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/markdown/core.py", line 216, in build_extension
#     entry_points = [ep for ep in util.get_installed_extensions() if ep.name == ext_name]
#   File "/Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/markdown/util.py", line 110, in get_installed_extensions
#     return metadata.entry_points(group='markdown.extensions')
# TypeError: entry_points() got an unexpected keyword argument 'group'

# %%
# data dimensions // hyperparameters 
input_dim = X_train_transformed.shape[1]
BATCH_SIZE = 256
EPOCHS = 100

# https://keras.io/layers/core/
autoencoder = tf.keras.models.Sequential([
    
    # deconstruct / encode
    tf.keras.layers.Dense(input_dim, activation='elu', input_shape=(input_dim, )), 
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(4, activation='elu'),
    tf.keras.layers.Dense(2, activation='elu'),
    
    # reconstruction / decode
    tf.keras.layers.Dense(4, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(input_dim, activation='elu')
    
])

# https://keras.io/api/models/model_training_apis/
autoencoder.compile(optimizer="adam", 
                    loss="mse",
                    metrics=["acc"])

# print an overview of our model
autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                240
#
#  dense_1 (Dense)             (None, 16)                256
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 4)                 36
#
#  dense_4 (Dense)             (None, 2)                 10
#
#  dense_5 (Dense)             (None, 4)                 12
#
#  dense_6 (Dense)             (None, 8)                 40
#
#  dense_7 (Dense)             (None, 16)                144
#
#  dense_8 (Dense)             (None, 15)                255
#
# =================================================================
# Total params: 1,129
# Trainable params: 1,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
from datetime import datetime

# current date and time
yyyymmddHHMM = datetime.now().strftime('%Y%m%d%H%M')

# new folder for a new run
log_subdir = f'{yyyymmddHHMM}_batch{BATCH_SIZE}_layers{len(autoencoder.layers)}'

# define our early stopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=10,
    verbose=1, 
    mode='min',
    restore_best_weights=True
)

save_model = tf.keras.callbacks.ModelCheckpoint(
    filepath='autoencoder_best_weights.hdf5',
    save_best_only=True,
    monitor='val_loss',
    verbose=0,
    mode='min'
)

tensorboard = tf.keras.callbacks.TensorBoard(
    f'logs/{log_subdir}',
    batch_size=BATCH_SIZE,
    update_freq='batch'
)

# callbacks argument only takes a list
cb = [early_stop, save_model, tensorboard]
# Out:
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.

# %%
history = autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=cb,
    validation_data=(X_validate_transformed, X_validate_transformed)
)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 5ms/step - loss: 0.3454 - acc: 0.0077 - val_loss: 0.2151 - val_acc: 0.0033
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1111 - acc: 0.0046 - val_loss: 0.0384 - val_acc: 0.0037
# Epoch 3/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0271 - acc: 0.5228 - val_loss: 0.0241 - val_acc: 0.8863
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0238 - acc: 0.8788 - val_loss: 0.0234 - val_acc: 0.8863
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0230 - acc: 0.8788 - val_loss: 0.0226 - val_acc: 0.8863
# Epoch 6/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0220 - acc: 0.8778 - val_loss: 0.0213 - val_acc: 0.8630
# Epoch 7/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0205 - acc: 0.8281 - val_loss: 0.0200 - val_acc: 0.8103
# Epoch 8/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0194 - acc: 0.7990 - val_loss: 0.0191 - val_acc: 0.7947
# Epoch 9/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0186 - acc: 0.7912 - val_loss: 0.0184 - val_acc: 0.7910
# Epoch 10/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0178 - acc: 0.8023 - val_loss: 0.0176 - val_acc: 0.8187
# Epoch 11/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0171 - acc: 0.8135 - val_loss: 0.0169 - val_acc: 0.8323
# Epoch 12/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0163 - acc: 0.8100 - val_loss: 0.0160 - val_acc: 0.8027
# Epoch 13/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0150 - acc: 0.7553 - val_loss: 0.0143 - val_acc: 0.7143
# Epoch 14/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0138 - acc: 0.7190 - val_loss: 0.0136 - val_acc: 0.7080
# Epoch 15/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0131 - acc: 0.7302 - val_loss: 0.0129 - val_acc: 0.7657
# Epoch 16/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0126 - acc: 0.7648 - val_loss: 0.0124 - val_acc: 0.7873
# Epoch 17/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0122 - acc: 0.7886 - val_loss: 0.0120 - val_acc: 0.7853
# Epoch 18/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0118 - acc: 0.7951 - val_loss: 0.0117 - val_acc: 0.8017
# Epoch 19/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0116 - acc: 0.7938 - val_loss: 0.0114 - val_acc: 0.8040
# Epoch 20/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0113 - acc: 0.7838 - val_loss: 0.0112 - val_acc: 0.7943
# Epoch 21/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0111 - acc: 0.7813 - val_loss: 0.0110 - val_acc: 0.7977
# Epoch 22/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0108 - acc: 0.7757 - val_loss: 0.0107 - val_acc: 0.7883
# Epoch 23/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0106 - acc: 0.7758 - val_loss: 0.0104 - val_acc: 0.7980
# Epoch 24/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0103 - acc: 0.7718 - val_loss: 0.0101 - val_acc: 0.7737
# Epoch 25/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0100 - acc: 0.7742 - val_loss: 0.0098 - val_acc: 0.7817
# Epoch 26/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0097 - acc: 0.7762 - val_loss: 0.0095 - val_acc: 0.7887
# Epoch 27/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0093 - acc: 0.7793 - val_loss: 0.0091 - val_acc: 0.7913
# Epoch 28/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0090 - acc: 0.7877 - val_loss: 0.0088 - val_acc: 0.7990
# Epoch 29/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0086 - acc: 0.7961 - val_loss: 0.0084 - val_acc: 0.8050
# Epoch 30/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0082 - acc: 0.8080 - val_loss: 0.0080 - val_acc: 0.8237
# Epoch 31/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0079 - acc: 0.8137 - val_loss: 0.0077 - val_acc: 0.8337
# Epoch 32/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0075 - acc: 0.8179 - val_loss: 0.0074 - val_acc: 0.8387
# Epoch 33/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0072 - acc: 0.8295 - val_loss: 0.0070 - val_acc: 0.8487
# Epoch 34/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0069 - acc: 0.8385 - val_loss: 0.0068 - val_acc: 0.8527
# Epoch 35/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0067 - acc: 0.8462 - val_loss: 0.0065 - val_acc: 0.8527
# Epoch 36/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0065 - acc: 0.8517 - val_loss: 0.0063 - val_acc: 0.8667
# Epoch 37/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0063 - acc: 0.8535 - val_loss: 0.0062 - val_acc: 0.8623
# Epoch 38/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0061 - acc: 0.8549 - val_loss: 0.0060 - val_acc: 0.8683
# Epoch 39/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0060 - acc: 0.8525 - val_loss: 0.0059 - val_acc: 0.8607
# Epoch 40/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0059 - acc: 0.8521 - val_loss: 0.0058 - val_acc: 0.8630
# Epoch 41/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0058 - acc: 0.8499 - val_loss: 0.0057 - val_acc: 0.8563
# Epoch 42/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - acc: 0.8493 - val_loss: 0.0056 - val_acc: 0.8570
# Epoch 43/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - acc: 0.8496 - val_loss: 0.0056 - val_acc: 0.8553
# Epoch 44/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0056 - acc: 0.8483 - val_loss: 0.0055 - val_acc: 0.8620
# Epoch 45/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0056 - acc: 0.8509 - val_loss: 0.0055 - val_acc: 0.8587
# Epoch 46/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - acc: 0.8487 - val_loss: 0.0055 - val_acc: 0.8563
# Epoch 47/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0055 - acc: 0.8497 - val_loss: 0.0054 - val_acc: 0.8563
# Epoch 48/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - acc: 0.8499 - val_loss: 0.0054 - val_acc: 0.8530
# Epoch 49/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0055 - acc: 0.8480 - val_loss: 0.0054 - val_acc: 0.8520
# Epoch 50/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - acc: 0.8486 - val_loss: 0.0054 - val_acc: 0.8543
# Epoch 51/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - acc: 0.8482 - val_loss: 0.0054 - val_acc: 0.8517
# Epoch 52/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - acc: 0.8489 - val_loss: 0.0054 - val_acc: 0.8520
# Epoch 53/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - acc: 0.8473 - val_loss: 0.0053 - val_acc: 0.8527
# Epoch 54/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - acc: 0.8472 - val_loss: 0.0053 - val_acc: 0.8603
# Epoch 55/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0054 - acc: 0.8478 - val_loss: 0.0053 - val_acc: 0.8500
# Epoch 56/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8472 - val_loss: 0.0053 - val_acc: 0.8527
# Epoch 57/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8468 - val_loss: 0.0053 - val_acc: 0.8580
# Epoch 58/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8462 - val_loss: 0.0052 - val_acc: 0.8533
# Epoch 59/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8459 - val_loss: 0.0052 - val_acc: 0.8533
# Epoch 60/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0053 - acc: 0.8440 - val_loss: 0.0052 - val_acc: 0.8540
# Epoch 61/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8439 - val_loss: 0.0052 - val_acc: 0.8533
# Epoch 62/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8419 - val_loss: 0.0052 - val_acc: 0.8523
# Epoch 63/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0053 - acc: 0.8436 - val_loss: 0.0052 - val_acc: 0.8497
# Epoch 64/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - acc: 0.8394 - val_loss: 0.0052 - val_acc: 0.8493
# Epoch 65/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - acc: 0.8407 - val_loss: 0.0052 - val_acc: 0.8513
# Epoch 66/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - acc: 0.8371 - val_loss: 0.0051 - val_acc: 0.8533
# Epoch 67/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - acc: 0.8367 - val_loss: 0.0051 - val_acc: 0.8420
# Epoch 68/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - acc: 0.8342 - val_loss: 0.0051 - val_acc: 0.8443
# Epoch 69/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - acc: 0.8326 - val_loss: 0.0051 - val_acc: 0.8373
# Epoch 70/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - acc: 0.8303 - val_loss: 0.0051 - val_acc: 0.8330
# Epoch 71/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0051 - acc: 0.8272 - val_loss: 0.0050 - val_acc: 0.8253
# Epoch 72/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - acc: 0.8236 - val_loss: 0.0050 - val_acc: 0.8353
# Epoch 73/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - acc: 0.8214 - val_loss: 0.0049 - val_acc: 0.8297
# Epoch 74/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - acc: 0.8193 - val_loss: 0.0049 - val_acc: 0.8260
# Epoch 75/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0049 - acc: 0.8158 - val_loss: 0.0048 - val_acc: 0.8230
# Epoch 76/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0048 - acc: 0.8077 - val_loss: 0.0047 - val_acc: 0.8250
# Epoch 77/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - acc: 0.8077 - val_loss: 0.0046 - val_acc: 0.8287
# Epoch 78/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0045 - acc: 0.8105 - val_loss: 0.0045 - val_acc: 0.8240
# Epoch 79/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0044 - acc: 0.8183 - val_loss: 0.0044 - val_acc: 0.8380
# Epoch 80/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0043 - acc: 0.8322 - val_loss: 0.0044 - val_acc: 0.8523
# Epoch 81/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0043 - acc: 0.8439 - val_loss: 0.0042 - val_acc: 0.8597
# Epoch 82/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0042 - acc: 0.8522 - val_loss: 0.0042 - val_acc: 0.8583
# Epoch 83/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0042 - acc: 0.8587 - val_loss: 0.0041 - val_acc: 0.8717
# Epoch 84/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0041 - acc: 0.8584 - val_loss: 0.0040 - val_acc: 0.8723
# Epoch 85/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0040 - acc: 0.8625 - val_loss: 0.0041 - val_acc: 0.8753
# Epoch 86/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0040 - acc: 0.8643 - val_loss: 0.0040 - val_acc: 0.8737
# Epoch 87/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0040 - acc: 0.8660 - val_loss: 0.0039 - val_acc: 0.8767
# Epoch 88/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - acc: 0.8687 - val_loss: 0.0040 - val_acc: 0.8760
# Epoch 89/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - acc: 0.8682 - val_loss: 0.0039 - val_acc: 0.8750
# Epoch 90/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - acc: 0.8701 - val_loss: 0.0039 - val_acc: 0.8810
# Epoch 91/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - acc: 0.8702 - val_loss: 0.0038 - val_acc: 0.8823
# Epoch 92/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.0038 - acc: 0.8698 - val_loss: 0.0038 - val_acc: 0.8773
# Epoch 93/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0038 - acc: 0.8693 - val_loss: 0.0038 - val_acc: 0.8820
# Epoch 94/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0038 - acc: 0.8683 - val_loss: 0.0038 - val_acc: 0.8803
# Epoch 95/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0038 - acc: 0.8677 - val_loss: 0.0038 - val_acc: 0.8773
# Epoch 96/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0038 - acc: 0.8682 - val_loss: 0.0037 - val_acc: 0.8763
# Epoch 97/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0037 - acc: 0.8670 - val_loss: 0.0038 - val_acc: 0.8803
# Epoch 98/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0038 - acc: 0.8662 - val_loss: 0.0037 - val_acc: 0.8777
# Epoch 99/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0037 - acc: 0.8655 - val_loss: 0.0038 - val_acc: 0.8777
# Epoch 100/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0037 - acc: 0.8656 - val_loss: 0.0037 - val_acc: 0.8723

# %% [markdown]
# ## Reconstruction

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
# 108/216 [==============>...............] - ETA: 0s
# /Users/junxingli/opt/anaconda3/envs/XingPythonKernel/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 216/216 [==============================] - 0s 463us/step

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed- reconstructions, 2), axis=1)

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

fig, ax = plt.subplots(figsize=(6,6))

ax.hist(clean, bins=50, density=True, label="clean", alpha=.6, color="green")
ax.hist(fraud, bins=50, density=True, label="fraud", alpha=.6, color="red")

plt.title("(Normalized) Distribution of the Reconstruction Loss")
plt.legend()
plt.show()
